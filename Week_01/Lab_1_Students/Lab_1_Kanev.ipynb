# %% [markdown]
# <a href="https://colab.research.google.com/github/Mechanics-Mechatronics-and-Robotics/CV-2025/blob/main/Week_01/Lab_1_Feature_Extraction_and_ML_teacher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab. \#1. Feature Extraction and Machine Learning
# By Алексей Канев.
#
# *01, 22, 2025.*

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The lab compares two approaches to machine learning (ML) and computer vision (CV). The *first approach* involves using an ML model for both automatic feature extraction and subsequent classification. The *second approach* processes hand-designed features, such as geometric features of objects in images, with an ML classification model. Historically, the second approach preceded the first. However, in modern coding, the first approach is easier to implement. Thus, this work is organized in order of increasing model complexity.
#
# The **main problem** addressed in this work is determining the better approach. The choice may not be straightforward, as many modern competitions related to CV problems, such as those submitted on [Kaggle](https://www.kaggle.com/competitions), often use a hybrid trick: instead of solving a CV problem directly with an image-processing model (e.g., a convolutional neural network or a visual transformer), the best solutions are often based on preliminary feature extraction followed by the analysis of tabular data using models like gradient boosting.
#
# The **dataset** used in this work is the MNIST database, consisting of $28\times28$ pixel images of handwritten digits, with a training subset of 60,000 examples and a test subset of 10,000 examples.
#
# The *first approach* can be implemented with a simple multi-layer perceptron (MLP) model to solve a multi-class classification problem by minimizing the cross-entropy (CE) loss, as described in [Prince, 2024](https://udlbook.github.io/udlbook/).
#
# The *second approach* can also be implemented using the same network architecture and loss function but with a modified dataset. In this case, the image dataset is replaced with a tabular dataset of hand-designed features. These features can be extracted using standard tools in [Scikit-learn](https://scikit-learn.org/1.5/modules/feature_extraction.html) or [OpenCV](https://docs.opencv.org/3.4/d0/d49/tutorial_moments.html).

# %% [markdown]
# ## Tasks and Requirements
#
# - Fill in your name and date information above.
# - Review the [Lightning framework](https://lightning.ai/docs/pytorch/stable/) (Level Up, Core API, Optional API sections of the manual).
# - Briefly review the [ClearML](https://clear.ml/docs/latest/docs/integrations/pytorch_lightning/) documentation.
# - Run the code below cell by cell and replace the placeholder text "Enter your code here" with your implementation in the missing code fragments.
# - If the code works properly, implement five parallel tests. Otherwise, fix the code before proceeding.
# - Fill in the table, add figures in the Results section, and complete the Conclusion section of the lab.
# - Address the Questions section and prepare to defend the lab.
#
# ### Bonus (complete one of the following as a bonus task):
# - Apply a t-SNE model to visualize both the original image dataset and the table dataset with hand-extracted features.
# - Add one or more features in the `TabularDataModule` to enhance the tabular model's capability.
# - Visualize the feature extraction process implemented in the `extract_features` function using one or more samples.
# - Apply a gradient boosting model to solve the table data classification problem in the second approach. Fine-tune both models to improve accuracy.
#
# ### A List of Blocks with Missing Code
# - Preparation of simulation models/Set the model/Logging
# - Approach #2: Hand-designed feature extraction followed by tabular data classification using the ANN.
# - Results and Discussion.
# - Conclusion.

# %% [markdown]
# # Preparation of simulation models

# %% [markdown]
# ## Import and Install Libraries

# %%
# !pip install pytorch-lightning clearml
# Out:
# Requirement already satisfied: pytorch-lightning in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (2.5.0.post0)
# Requirement already satisfied: clearml in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (1.17.1)
# Requirement already satisfied: torch>=2.1.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (2.5.1)
# Requirement already satisfied: tqdm>=4.57.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: PyYAML>=5.4 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: fsspec>=2022.5.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2024.6.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (1.6.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (24.1)
# Requirement already satisfied: typing-extensions>=4.4.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.10.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from pytorch-lightning) (0.11.9)
# Requirement already satisfied: attrs>=18.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (24.3.0)
# Requirement already satisfied: furl>=2.0.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.1.2)
# Requirement already satisfied: jsonschema>=2.6.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (4.23.0)
# Requirement already satisfied: numpy>=1.10 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (1.26.4)
# Requirement already satisfied: pathlib2>=2.3.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.3.6)
# Requirement already satisfied: Pillow>=4.1.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (11.0.0)
# Requirement already satisfied: psutil>=3.4.2 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (6.1.0)
# Requirement already satisfied: pyparsing>=2.0.3 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.9.0.post0)
# Requirement already satisfied: pyjwt<2.10.0,>=2.4.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.8.0)
# Requirement already satisfied: referencing<0.40 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (0.30.2)
# Requirement already satisfied: requests>=2.20.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.32.3)
# Requirement already satisfied: six>=1.16.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (1.16.0)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from clearml) (2.2.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.11.11)
# Requirement already satisfied: orderedmultidict>=1.0.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from furl>=2.0.0->clearml) (1.0.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from jsonschema>=2.6.0->clearml) (2023.7.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from jsonschema>=2.6.0->clearml) (0.22.3)
# Requirement already satisfied: setuptools in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (72.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from requests>=2.20.0->clearml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from requests>=2.20.0->clearml) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from requests>=2.20.0->clearml) (2024.12.14)
# Requirement already satisfied: filelock in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.13.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (1.13.1)
# Requirement already satisfied: networkx in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from sympy==1.13.1->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: colorama in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from tqdm>=4.57.0->pytorch-lightning) (0.4.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.18.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lexan\miniconda3\envs\mainenv\lib\site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (2.1.3)

# %%
#Pytorch modules
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader, random_split, TensorDataset
from torchvision.datasets import MNIST
from torchvision import datasets, transforms
#sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
#Numpy
import numpy as np
#Pandas
import pandas as pd
#Lightning & logging
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint
#Image processing (OpenCV)
import cv2
#Data observation
import os
from pathlib import Path
#Plotting
import matplotlib.pyplot as plt
import seaborn as sns
#Logging
from clearml import Task

# %% [markdown]
# ## Set the Models

# %% [markdown]
# ### Simulation Settings

# %% [markdown]
# Check the current directory

# %%
os.getcwd() #returns the current working directory
# Out:
# 'c:\\Users\\lexan\\OneDrive\\Документы\\Python\\IU\\CV'

# %%
# Path to the folder where the pretrained models are saved
CHECKPOINT_PATH = os.environ.get("PATH_CHECKPOINT", "saved_models/")
print(f'CHECKPOINT_PATH: {CHECKPOINT_PATH}')

os.makedirs(CHECKPOINT_PATH, exist_ok=True)
# Out:
# CHECKPOINT_PATH: saved_models/

# %% [markdown]
# Set the reproducibility options

# %%
# Function for setting the seed to implement parallel tests
SEED = 42 # random seeds are 42, 0, 17, 9, 3
pl.seed_everything(SEED)

os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# # Ensure that all operations are deterministic on GPU (if used) for reproducibility
# torch.backends.cudnn.deterministic = True
# torch.backends.cudnn.benchmark = False
# torch.use_deterministic_algorithms(True)

# torch.manual_seed(SEED)
# np.random.seed(SEED)
# Out:
# Seed set to 42

# %% [markdown]
# ### Logging

# %% [markdown]
# To configure ClearML in your Colab environment, follow these steps:
#
# ---
#
# *Step 1: Create a ClearML Account*
# 1. Go to the [ClearML website](https://clear.ml/).
# 2. Sign up for a free account if you don’t already have one.
# 3. Once registered, log in to your ClearML account.
#
# ---
#
# *Step 2: Get Your ClearML Credentials*
# 1. After logging in, navigate to the **Settings** page (click on your profile icon in the top-right corner and select **Settings**).
# 2. Under the **Workspace** section, find your **+ Create new credentials**.
# 3. Copy these credentials for a Jupiter notebook into the code cell below.
#
# ---
#
# *Step 3: Accessing the ClearML Dashboard*
# 1. Go to your ClearML dashboard (https://app.clear.ml).
# 2. Navigate to the **Projects** section to see your experiments.
# 3. Click on the experiment (e.g., `Lab_1`) to view detailed metrics, logs, and artifacts.
#
# ---

# %%
#Enter your code here to implement Step 2 of the logging instruction as it is shown below
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=CATABEDJ9F8VBHNAT6LFQIYCURQ8ZJ
# %env CLEARML_API_SECRET_KEY=47Xedb8WDFNGQRm61ogP-_EWozDwMI3_HoQwoZy5mmiC8JI3I_8A5DtSj4NmM3-nnkU
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=CATABEDJ9F8VBHNAT6LFQIYCURQ8ZJ
# env: CLEARML_API_SECRET_KEY=47Xedb8WDFNGQRm61ogP-_EWozDwMI3_HoQwoZy5mmiC8JI3I_8A5DtSj4NmM3-nnkU

# %%
# task = Task.init(project_name="CV-2025", task_name=f'Lab_1_seed={SEED}_img')
# print("ClearML is configured correctly!") #just to make you feel better

# %% [markdown]
# ### Dataset

# %% [markdown]
# Summary

# %%
DATASET = 'MNIST'
NS = {
    'train': 55000,
    'val': 5000,
    'test': 10000
} # for MNIST

SIZE = 28 #image size
NUM_CLASSES = 10
CLASS_NAMES = ['zero' ,'one', 'two', 'three', 'four',
               'five', 'six', 'seven', 'eight', 'nine']

# %% [markdown]
# Normalization parameters

# %%
#For the MNIST dataset
MEAN = np.array([0.1307])
STD  = np.array([0.3081])

# %% [markdown]
# Transforms

# %% [markdown]
# ### Collect parameters

# %%
#Model parameters
LOSS_FUN = 'CE' # 'CE', etc.
ARCHITECTURE = 'MLP' # 'MLP', etc.

#Collect the parameters (hyperparams and others)
hparams = {
    'seed':SEED,
    "lr": 0.0001,
    'weight_decay': 0.0,
    "dropout": 0.0,
    "bs": 64,
    "num_workers": 2,
    "num_epochs": 5,
    "criterion": LOSS_FUN,
    "num_samples": NS,
    "im_size": SIZE,
    "mean": MEAN,
    "std": STD,
    "n_classes": 10,
    'n_ext_features': 14
}
#Visualization
vis_params = {
    'fig_size': 5,
    'num_samples': 5,
    'num_bins': 50,
}

# %% [markdown]
# ## Functions

# %% [markdown]
# ### Lightning

# %% [markdown]
# Data module

# %%
# Approach #1: dataset of images
class MNISTDataModule(pl.LightningDataModule):
    def __init__(self, params):
        super().__init__()
        self.seed = params['seed']
        self.batch_size = params['bs']
        self.num_workers = params['num_workers']
        self.mean = params['mean']
        self.std =  params['std']
        self.ns = params['num_samples']
        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize(self.mean, self.std)
        ])

    def prepare_data(self):
        # Download MNIST dataset
        datasets.MNIST(root='./data', train=True, download=True)
        datasets.MNIST(root='./data', train=False, download=True)

    def setup(self, stage=None):
        # Split dataset into train and validation sets
        mnist_full = datasets.MNIST(root='./data', train=True,
                                    transform=self.transform)
        pl.seed_everything(self.seed)
        self.mnist_train, self.mnist_val = random_split(mnist_full,
                                                        [self.ns['train'],
                                                         self.ns['val']])
        self.mnist_test = datasets.MNIST(root='./data', train=False,
                                         transform=self.transform)

    def train_dataloader(self):
        return DataLoader(self.mnist_train, batch_size=self.batch_size,
                          num_workers=self.num_workers, shuffle=True)
    def val_dataloader(self):
        return DataLoader(self.mnist_val, batch_size=self.batch_size,
                          num_workers=self.num_workers)
    def test_dataloader(self):
        return DataLoader(self.mnist_test, batch_size=self.batch_size,
                          shuffle=False,)

# Approach #2: tabular dataset of extracted features
class TabularDataModule(MNISTDataModule):
    def __init__(self, params):
        super().__init__(params)
        self.feature_names = [
            'mean_intensity', 'std_intensity', 'num_edges',
            'aspect_ratio', 'cx', 'cy', 'num_contours', 'area',
            'perimeter', 'inertia', 'compactness', 'eccentricity'
        ]
        self.scaler = StandardScaler()  # Initialize the StandardScaler

    def setup(self, stage=None):
        # Call the parent class's setup method to load and split the MNIST dataset
        super().setup(stage)

        # Extract features from the MNIST datasets
        self.train_features, self.train_labels = self._extract_features(self.mnist_train)
        self.val_features, self.val_labels = self._extract_features(self.mnist_val)
        self.test_features, self.test_labels = self._extract_features(self.mnist_test)

        # Normalize the features using StandardScaler
        self.scaler.fit(self.train_features)  # Fit the scaler on the training data
        self.train_features = self.scaler.transform(self.train_features)
        self.val_features = self.scaler.transform(self.val_features)
        self.test_features = self.scaler.transform(self.test_features)

    def _extract_features(self, dataset):
        """
        Extract features from a dataset of MNIST images.
        :param dataset: A PyTorch dataset of MNIST images.
        :return: A tuple (features, labels) where features is a NumPy array and labels is a NumPy array.
        """
        features = []
        labels = []
        for image, label in dataset:
            # Convert image to numpy array
            image_np = image.squeeze().numpy()

            # Extract features
            feature_vector = extract_features(image_np)
            features.append(feature_vector)
            labels.append(label)

        return np.array(features), np.array(labels)

    def train_dataloader(self):
        # Create a TensorDataset from features and labels
        train_dataset = TensorDataset(
            torch.tensor(self.train_features, dtype=torch.float32),
            torch.tensor(self.train_labels, dtype=torch.long)
        )
        return DataLoader(train_dataset, batch_size=self.batch_size,
                          shuffle=True, num_workers=self.num_workers)

    def val_dataloader(self):
        # Create a TensorDataset from features and labels
        val_dataset = TensorDataset(
            torch.tensor(self.val_features, dtype=torch.float32),
            torch.tensor(self.val_labels, dtype=torch.long)
        )
        return DataLoader(val_dataset, batch_size=self.batch_size,
                          num_workers=self.num_workers)

    def test_dataloader(self):
        # Create a TensorDataset from features and labels
        test_dataset = TensorDataset(
            torch.tensor(self.test_features, dtype=torch.float32),
            torch.tensor(self.test_labels, dtype=torch.long)
        )
        return DataLoader(test_dataset, batch_size=self.batch_size,
                          num_workers=self.num_workers)

# %% [markdown]
# Training module

# %%
class train_model(pl.LightningModule):
    def __init__(self, model=None, losses_dict=None, hparams=hparams):
    # def __init__(self, hparams=hparams):
        super().__init__()
        self.save_hyperparameters(hparams)
        self.model = model
        self.loss_fn = losses_dict[hparams['criterion']]
        self.lr = hparams['lr']
        self.wd = hparams['weight_decay']

    def forward(self, x):
        return self.model(x)

    def training_step(self, batch, batch_idx):
        x, y = batch
        h = self(x)
        loss = self.loss_fn(h, y)
        self.log('train_loss', loss)
        return loss

    def validation_step(self, batch, batch_idx):
        x, y = batch
        h = self(x)
        loss = self.loss_fn(h, y)
        self.log('val_loss', loss, logger=True, on_step=True)
        return loss

    def test_step(self, batch, batch_idx):
        x, y = batch
        h = self(x)
        loss = self.loss_fn(h, y)
        preds = torch.argmax(h, dim=1)
        acc = (preds == y).float().mean()
        self.log('test_loss', loss)
        self.log('test_acc', acc)
        return {'loss': loss, 'preds': preds, 'y': y}

    def configure_optimizers(self):
        return torch.optim.Adam(self.parameters(), lr=self.lr,
                                weight_decay=self.wd)

# %% [markdown]
# Callbacks

# %%
# Define the ModelCheckpoint callbacks to save the best validation models
#Approach #1
checkpoint_callback_img = ModelCheckpoint(
    monitor='val_loss',       # Monitor validation loss
    dirpath=CHECKPOINT_PATH,  # Directory to save checkpoints
    filename=f'best_model_{ARCHITECTURE}_{SEED}_img',# Checkpoint filename
    save_top_k=1,             # Save only the best model
    mode='min',               # Minimize validation loss
)
#Approach #2
checkpoint_callback_tab = ModelCheckpoint(
    monitor='val_loss',       # Monitor validation loss
    dirpath=CHECKPOINT_PATH,  # Directory to save checkpoints
    filename=f'best_model_{ARCHITECTURE}_{SEED}_tab',# Checkpoint filename
    save_top_k=1,             # Save only the best model
    mode='min',               # Minimize validation loss
)

# %% [markdown]
# ### Models

# %% [markdown]
# MLP

# %%
class MLP(nn.Module):
    def __init__(self, input_size=None, params=hparams):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, params['n_classes'])
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(params['dropout'])

    def forward(self, x):
        # Flatten the input if it's an image (shape: [batch_size, 1, im_size, im_size])
        if x.dim() == 4:  # Check if input is an image
            x = x.view(x.size(0), -1)  # Flatten to [batch_size, im_size * im_size]
        elif x.dim() == 2:  # Check if input is tabular data (shape: [batch_size, n_feat])
            pass  # No need to flatten
        else:
            raise ValueError(f"Unexpected input shape: {x.shape}. Expected [batch_size, 1, im_size, im_size] or [batch_size, n_feat].")
        x = x.view(x.size(0), -1)  # Flatten the input
        x = self.relu(self.fc1(x))
        x = self.dropout(x)
        x = self.relu(self.fc2(x))
        x = self.dropout(x)
        x = self.fc3(x)
        return x

# %% [markdown]
# ### Loss functions

# %% [markdown]
# Create a loss function class, or use a standart one.

# %%
# Cross entropy loss maden from scratch (just in case)
class CEplus(nn.Module):
    def __init__(self, reduction='mean'):
        super(CEplus, self).__init__()
        self.reduction = reduction

    def forward(self, x, y):
        # Compute softmax probabilities
        prob = nn.functional.softmax(x, 1)
        # Compute log probabilities
        log_prob = -1.0 * torch.log(prob)
        # Gather the log probabilities for the true labels
        loss = log_prob.gather(1, y.unsqueeze(1))
        # Apply reduction
        if self.reduction == 'mean':
            loss = loss.mean()
        elif self.reduction == 'sum':
            loss = loss.sum()
        elif self.reduction == 'none':
            loss = loss.squeeze()  # Remove extra dimension for consistency
        else:
            raise ValueError("Invalid reduction option.")

        return loss

losses_dict = {'CE': nn.CrossEntropyLoss(),
               'CEplus': CEplus(),
}
losses_dict_red = {'CE': nn.CrossEntropyLoss(reduction='none'),
                   'CEplus': CEplus(reduction='none'),
}

# %% [markdown]
# ### Metrics

# %%
def metrics(dataloader,model,loss_fn_red):
    # Collect images, predictions, and losses
    images = []
    preds  = []
    labels = []
    losses = []
    correct= 0
    total  = 0
    for batch in dataloader:
        x, y = batch
        with torch.no_grad():
            h = model(x)
            loss = loss_fn_red(h,y)
            pred = torch.argmax(h, dim=1)
        correct += (pred == y).sum().item()  # Number of correct predictions
        total += y.size(0)  # Total number of samples

        images.extend(x.cpu())
        preds.extend(pred.cpu().numpy())
        labels.extend(y.cpu().numpy())
        losses.extend(loss.cpu().numpy())
    acc = correct / total
    return images, preds, labels, losses, acc

# %% [markdown]
# ### Feature extractor
#
# Extracts geometric features of images

# %%
def extract_features(image):
    """
    Extract geometric and statistical features from a single MNIST image.
    :param image: A 28x28 numpy array (MNIST image).
    :return: A list of features.
    """
    features = []

    # Normalize the image to [0, 255] for better thresholding
    image = (image * 255).astype(np.uint8)

    # 1. Mean Pixel Intensity
    mean_intensity = np.mean(image)
    features.append(mean_intensity)

    # 2. Standard Deviation of Pixel Intensity
    std_intensity = np.std(image)
    features.append(std_intensity)

    # 3. Number of Edges (using Sobel filter)
    sobel_x = cv2.Sobel(image, cv2.CV_64F, 1, 0, ksize=3)
    sobel_y = cv2.Sobel(image, cv2.CV_64F, 0, 1, ksize=3)
    edges = np.sqrt(sobel_x**2 + sobel_y**2)
    num_edges = np.sum(edges > 50)  # Threshold to count edges
    features.append(num_edges)

    # 4. Aspect Ratio
    _, binary_image = cv2.threshold(image, 128, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    if len(contours) > 0:
        x, y, w, h = cv2.boundingRect(contours[0])
        aspect_ratio = float(w) / h if h != 0 else 0
    else:
        aspect_ratio = 0
    features.append(aspect_ratio)

    # 5. Center of Mass
    moments = cv2.moments(image)
    if moments["m00"] != 0:
        cx = moments["m10"] / moments["m00"]
        cy = moments["m01"] / moments["m00"]
    else:
        cx, cy = 0, 0
    features.append(cx)
    features.append(cy)

    # 6. Number of Contours
    num_contours = len(contours)
    features.append(num_contours)

    # 7. Area of the Digit
    if len(contours) > 0:
        area = cv2.contourArea(contours[0])
    else:
        area = 0
    features.append(area)

    # 8. Perimeter Length
    if len(contours) > 0:
        perimeter = cv2.arcLength(contours[0], closed=True)
    else:
        perimeter = 0
    features.append(perimeter)

    # 9. Inertia (Second Moment of Area)
    if len(contours) > 0:
        inertia = moments["mu20"] + moments["mu02"]
    else:
        inertia = 0
    features.append(inertia)

    # 10. Compactness (Perimeter^2 / Area)
    if area > 0:
        compactness = (perimeter ** 2) / area
    else:
        compactness = 0
    features.append(compactness)

    # 11. Eccentricity
    if len(contours) > 0 and len(contours[0]) >= 5:  # Check if contour has at least 5 points
        (_, _), (major_axis, minor_axis), _ = cv2.fitEllipse(contours[0])

        # Ensure minor_axis <= major_axis
        if minor_axis > major_axis:
            major_axis, minor_axis = minor_axis, major_axis

        # Clip the argument of np.sqrt to ensure it is non-negative
        ratio = (minor_axis ** 2) / (major_axis ** 2)
        ratio = np.clip(ratio, 0, 1)  # Clip to [0, 1]

        eccentricity = np.sqrt(1 - ratio)
    else:
        eccentricity = 0
    features.append(eccentricity)

    # Enter your code here to add one or more additional features (bonus track)
    ##############################################
    # 12. Number of corners (using Harris corner detection)
    corners = cv2.cornerHarris(image, blockSize=2, ksize=3, k=0.04)
    n_corners = np.sum(corners > 0.05 * corners.max())
    features.append(n_corners)

    # 13. Number of lines (using Hough line detection)
    lines = cv2.HoughLines(image, rho=1, theta=np.pi/180, threshold=50)
    n_lines = 0 if lines is None else len(lines)
    features.append(n_lines)
    ###############################################

    return features

def create_tabular_dataset(dataset):
    """
    Create a tabular dataset from MNIST images by extracting features.
    :param dataset: MNIST dataset (e.g., torchvision.datasets.MNIST).
    :return: A tuple (X, y) where X is the feature matrix and y is the label vector.
    """
    X = []
    y = []

    for image, label in dataset:
        # Convert image to numpy array
        image_np = image.squeeze().numpy()

        # Extract features
        features = extract_features(image_np)
        X.append(features)
        y.append(label)

    return np.array(X), np.array(y)

# %% [markdown]
# ### Visualization

# %%
# Plot image samples with top loss values
def top_losses_vis(vis_params, images, preds, labels, losses):
    num_imgs = vis_params['num_samples']
    top_loss_indices = np.argsort(losses)[-num_imgs:]

    plt.figure(figsize=(num_imgs*2, 2))
    for i, idx in enumerate(top_loss_indices):
        plt.subplot(1, num_imgs, i + 1)
        plt.imshow(images[idx].squeeze(), cmap='gray')
        plt.title(f'True: {labels[idx]}\nPred: {preds[idx]}\nLoss: {losses[idx]:.2f}')
        plt.axis('off')
    plt.show()

# Plot confusion matrix
def conf_mat(cm, figsize):
    plt.figure(figsize)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=range(10), yticklabels=range(10))
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# %%
loss_fn = losses_dict[hparams['criterion']]
loss_fn_red = losses_dict_red[hparams['criterion']]

# %% [markdown]
# # Approach \# 1: Feature Extraction and Image Classification Using an ANN

# %% [markdown]
# Note: historically, approach #1 is more modern than appooach #2 presented in the next chapter of this notebook.

# %% [markdown]
# ## Create Dataset and Data Loaders

# %% [markdown]
# Initialization of the dataset, the dataloader, and the training module

# %%
data_module = MNISTDataModule(hparams)

# %% [markdown]
# ## Train the Model

# %% [markdown]
# Initialize the loss function, and it's version with reduction to calculate loss per image

# %%
loss_fn = losses_dict[hparams['criterion']]
loss_fn_red = losses_dict_red[hparams['criterion']]

# %% [markdown]
# Initialize the model and the trainer. Log the hyperparameters

# %%
pl.seed_everything(SEED) #on more time, just in case
model = train_model(model=MLP(input_size=hparams['im_size']**2), losses_dict=losses_dict)
# Log hyperparameters to ClearML
task.connect(model.hparams)

trainer = Trainer(max_epochs=hparams['num_epochs'],
                  callbacks=[checkpoint_callback_img],
                  accelerator="auto", devices="auto")
# Out:
# Seed set to 42
# 2025-01-22 20:16:17,411 - clearml.Task - WARNING - Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\logger_connector\logger_connector.py:76: UserWarning:
#
# Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `pytorch_lightning` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %% [markdown]
# Train the model

# %%
trainer.fit(model, data_module)
# Out:
# You are using a CUDA device ('NVIDIA GeForce RTX 4070 Ti SUPER') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Seed set to 42
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:654: UserWarning:
#
# Checkpoint directory C:\Users\lexan\OneDrive\Документы\Python\IU\CV\saved_models exists and is not empty.
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 0: 100%|██████████| 860/860 [00:05<00:00, 152.44it/s, v_num=39]2025-01-22 20:16:32,903 - clearml.frameworks - INFO - Found existing registered model id=186d0474c9074ed6a52bb8401769aaba [C:\Users\lexan\OneDrive\Документы\Python\IU\CV\saved_models\best_model_MLP_42_img-v4.ckpt] reusing it.
# Epoch 4: 100%|██████████| 860/860 [00:09<00:00, 87.76it/s, v_num=39]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:18<00:00, 47.47it/s, v_num=39]

# %% [markdown]
# Log the best model

# %%
best_model_path = checkpoint_callback_img.best_model_path
task.update_output_model(model_path=best_model_path, auto_delete_file=False)
# Out:
# 2025-01-22 20:18:01,437 - clearml.storage - INFO - Starting upload: C:\Users\lexan\OneDrive\Документы\Python\IU\CV\saved_models\best_model_MLP_42_img-v4.ckpt => https://files.clear.ml/CV-2025/Lab_1_seed=42_img.42a2a011088a4d16b508bfc58f37d1f9/models/best_model_MLP_42_img-v4.ckpt
# 'https://files.clear.ml/CV-2025/Lab_1_seed=42_img.42a2a011088a4d16b508bfc58f37d1f9/models/best_model_MLP_42_img-v4.ckpt'

# %% [markdown]
# ## Test the Model

# %%
checkpoint_callback_img.best_model_path
# Out:
# 'C:\\Users\\lexan\\OneDrive\\Документы\\Python\\IU\\CV\\saved_models\\best_model_MLP_42_img-v4.ckpt'

# %% [markdown]
# Load the best model checkpoint

# %%
best_model = train_model.load_from_checkpoint(best_model_path,
                                              model=MLP(input_size=hparams['im_size']**2),
                                              losses_dict=losses_dict)
# Out:
# 2025-01-22 20:18:02,039 - clearml.model - INFO - Selected model id: 186d0474c9074ed6a52bb8401769aaba
# 2025-01-22 20:18:04,946 - clearml.Task - INFO - Completed model upload to https://files.clear.ml/CV-2025/Lab_1_seed%3D42_img.42a2a011088a4d16b508bfc58f37d1f9/models/best_model_MLP_42_img-v4.ckpt
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\utilities\parsing.py:209: UserWarning:
#
# Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.

# %% [markdown]
# The Metric and the loss values for the test set (for a batch, probably)

# %%
test_results = trainer.test(best_model, datamodule=data_module)
print(test_results)
# Out:
# Seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:425: PossibleUserWarning:
#
# The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=15` in the `DataLoader` to improve performance.
# Testing DataLoader 0: 100%|██████████| 157/157 [00:01<00:00, 97.16it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.9526000022888184
#         test_loss           0.1631832867860794
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.1631832867860794, 'test_acc': 0.9526000022888184}]

# %% [markdown]
# The metrics for the entire test set

# %%
test_images, test_preds, test_labels, test_losses, test_acc =  metrics(data_module.test_dataloader(),
                                                             best_model, loss_fn_red)
print(f'Accuracy for the entire test set is: {test_acc}')
# Compute confusion matrix
cm = confusion_matrix(test_labels, test_preds)
# Out:
# Accuracy for the entire test set is: 0.9526

# %% [markdown]
# Visualize the test results

# %% [markdown]
# With the confusion matrix for the test set

# %%
conf_mat(cm, vis_params['fig_size'])

# %% [markdown]
# With the test samples of top losses

# %%
top_losses_vis(vis_params, test_images, test_preds, test_labels, test_losses)

# %% [markdown]
# Clear some memory and stop logging the task

# %%
del data_module, model, trainer, best_model, test_images, test_preds, test_labels, test_losses
task.close()

# %% [markdown]
# # Approach \# 2: Hand-Designed Feature Extraction and the Following Tabular Data Classification using the ANN

# %% [markdown]
# ## Start Tracking a New Task

# %%
# Enter your code here to create a new task entiteled f'Lab_1_seed={SEED}_tab'
#in the same project
task2 = Task.create(project_name="CV-2025", task_name=f'Lab_1_seed={SEED}_tab')

# %% [markdown]
# ## Create Dataset and Data Loaders

# %%
# Enter your code here to:
# Initialize the TabularDataModule
# data_module = ...
data_module = TabularDataModule(hparams)

# Prepare and setup the data
data_module.prepare_data()
data_module.setup()

# Example: Access the training data, check if the feature and labels shapes are correct
train_dataloader = data_module.train_dataloader()
for batch in train_dataloader:
    features, labels = batch
    print("Features shape:", features.shape)  # Should be (batch_size, num_features)
    print("Labels shape:", labels.shape)      # Should be (batch_size,)
    break
# Out:
# Seed set to 42
# Features shape: torch.Size([64, 14])
# Labels shape: torch.Size([64])

# %% [markdown]
# ## Train the Model

# %% [markdown]
# Initialization of the dataset, the dataloader, and the training module

# %%
from pytorch_lightning.callbacks import EarlyStopping

pl.seed_everything(SEED) #just in case
#Enter your code here to create the model
#model = ...
model = train_model(model=MLP(input_size=hparams['n_ext_features']), losses_dict=losses_dict)

early_stop_callback = EarlyStopping(
    monitor='val_loss',
    patience=3,
    verbose=False,
    mode='min',
    min_delta=0.01
)
# Log hyperparameters to ClearML
task2.connect(model.hparams)
# Start the trainer with appropriate callbacks
trainer = Trainer(max_epochs=5,
                  callbacks=[checkpoint_callback_tab, early_stop_callback],
                  accelerator="auto", devices="auto")
# Out:
# Seed set to 42
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
#Check if the model looks fine
model
# Out:
# train_model(
#   (model): MLP(
#     (fc1): Linear(in_features=14, out_features=128, bias=True)
#     (fc2): Linear(in_features=128, out_features=64, bias=True)
#     (fc3): Linear(in_features=64, out_features=10, bias=True)
#     (relu): ReLU()
#     (dropout): Dropout(p=0.0, inplace=False)
#   )
#   (loss_fn): CrossEntropyLoss()
# )

# %% [markdown]
# Train the model

# %%
trainer.fit(model, data_module)
# Out:
# Seed set to 42
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\callbacks\model_checkpoint.py:654: UserWarning:
#
# Checkpoint directory C:\Users\lexan\OneDrive\Документы\Python\IU\CV\saved_models exists and is not empty.
#
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:05<00:00, 145.75it/s, v_num=16]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:05<00:00, 145.60it/s, v_num=16]

# %% [markdown]
# Log the best model

# %%
# Enter your code here to define the best model path
# best_model_path =
task2.update_output_model(model_path=best_model_path, auto_delete_file=False)
# Out:
# 'https://files.clear.ml/CV-2025/Lab_1_seed=42_tab.a7dc890f4524418fa937e1e1d4d6ce1a/models/best_model_MLP_42_img-v4.ckpt'

# %% [markdown]
# ## Test the Model

# %%
best_model_path= checkpoint_callback_tab.best_model_path

# %%
best_model_path = 'c:\\Users\\lexan\\OneDrive\\Документы\\Python\\IU\\CV/saved_models/best_model_MLP_42_tab-v4.ckpt'

# %% [markdown]
# Load the best model checkpoint

# %%
# Enter your code here to load the best model from the checkpoint usine features.shape[-1] as the input size
# best_model =
best_model = train_model.load_from_checkpoint(best_model_path,
                                              model=MLP(input_size=hparams['n_ext_features']),
                                              losses_dict=losses_dict)
# Out:
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\utilities\parsing.py:209: UserWarning:
#
# Attribute 'model' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['model'])`.

# %% [markdown]
# The Metric and the loss values for the test set (for a batch, probably)

# %%
test_results = trainer.test(best_model, datamodule=data_module)
print(test_results)
# Out:
# Seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'test_dataloader' to speed up the dataloader worker initialization.
# Testing DataLoader 0: 100%|██████████| 157/157 [00:00<00:00, 384.69it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.3393000066280365
#         test_loss           1.7593621015548706
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 1.7593621015548706, 'test_acc': 0.3393000066280365}]

# %% [markdown]
# The metrics for the entire test set

# %%
test_images, test_preds, test_labels, test_losses, test_acc =  metrics(data_module.test_dataloader(),
                       best_model, loss_fn_red)
print(f'Accuracy for the entire test set is: {test_acc}')
# Compute confusion matrix
cm = confusion_matrix(test_labels, test_preds)
# Out:
# Accuracy for the entire test set is: 0.3393

# %% [markdown]
# Visualize the test results

# %% [markdown]
# With the confusion matrix for the test set

# %%
# Enter your code here to visualize the confusion matrix
conf_mat(cm, vis_params['fig_size'])

# %% [markdown]
# ## Stop Logging

# %%
task2.close()

# %% [markdown]
# # Results and Discussion

# %% [markdown]
# All experiments were performed five times with random seeds of [42, 0, 17, 9, 3] (see the table below). The final metrics were calculated as means and standard deviations over five runs. The minimum values of the loss function on validation determined the best checkpoints of the models (see Figure 1).

# %% [markdown]
# !!! Please implement the experiments, fill the table and plot the figure below. !!!

# %% [markdown]
# **Table 1.** Results of a series of simulation experiments on the MNIST dataset comparing two approaches: automatic feature extraction using an artificial neural network (ANN), and a hand-designed feature extractor combined with an ANN classifier.
#
# | # | Approach     | Arch.| #train.param. | Seed | Accuracy, \%|
# |---|--------------|------|---------------|------|-------------|
# | 1 | Img. classif.| MLP  | 109E+3        | 42   | 95.17       |
# |   | Img. classif.| MLP  | 109E+3        | 0    | 95.16       |
# |   | Img. classif.| MLP  | 109E+3        | 17   | 94.81       |
# |   | Img. classif.| MLP  | 109E+3        | 9    | 95.33       |
# |   | Img. classif.| MLP  | 109E+3        | 3    | 95.2        |
# |---|--------------|------|---------------|------|-------------|
# | 2 | Tab. classif.| MLP  | 10 826        | 42   | 33.93       |
# |   | Tab. classif.| MLP  | 10 826        | 0    | 34.01       |
# |   | Tab. classif.| MLP  | 10 826        | 17   | 33.58       |
# |   | Tab. classif.| MLP  | 10 826        | 9    | 33.94       |
# |   | Tab. classif.| MLP  | 10 826        | 3    | 33.96       |

# %%
def train_test_and_obtain_res(data_module, hparams, task, approach):
    pl.seed_everything(hparams['seed']) #on more time, just in case
    os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'
    model = train_model(model=MLP(input_size=hparams['input_size']), losses_dict=losses_dict)
    task.connect(model.hparams)

    trainer = Trainer(max_epochs=hparams['num_epochs'],
                  accelerator="gpu", devices='auto')
    
    data_module.prepare_data()
    data_module.setup()

    trainer.fit(model, data_module)
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    
    *_, test_acc =  metrics(data_module.test_dataloader(),
                            model, loss_fn_red)
    return {'tr-ble_params':trainable_params, "seed": hparams['seed'], "accuracy": test_acc}

# %%
import time
hparams_tab = hparams.copy()
hparams_img = hparams.copy()
hparams_tab['input_size'] = hparams['n_ext_features']
hparams_img['input_size'] = hparams['im_size']**2

seeds = [42, 0, 17, 9, 3]

for seed in seeds:
    hparams_tab['seed'] = seed
    hparams_img['seed'] = seed

    task_tab = Task.init(project_name="CV-2025", task_name=f'Lab_1_seed={seed}_tab')
    res_tab = train_test_and_obtain_res(TabularDataModule(hparams_tab), hparams_tab, task_tab, 'tab')
    task_tab.close()
    time.sleep(2)
    task_img = Task.init(project_name="CV-2025", task_name=f'Lab_1_seed={seed}_img')
    res_img = train_test_and_obtain_res(MNISTDataModule(hparams_img), hparams_img, task_img, 'img')
    task_img.close()

    print(res_tab, res_img)
# Out:
# ClearML Task: created new task id=216ac17ddf0a491284d640290b10fa05
# 2025-01-23 10:20:48,188 - clearml.Repository Detection - WARNING - Could not read Jupyter Notebook: No module named 'nbconvert'
# 2025-01-23 10:20:48,189 - clearml.Task - INFO - Storing jupyter notebook directly as code
# 2025-01-23 10:20:48,189 - clearml.Repository Detection - WARNING - Please install nbconvert using "pip install nbconvert"
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/216ac17ddf0a491284d640290b10fa05/output/log
# Seed set to 42
# 2025-01-23 10:20:51,266 - clearml.Task - WARNING - Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 42
# You are using a CUDA device ('NVIDIA GeForce RTX 4070 Ti SUPER') that has Tensor Cores. To properly utilize them, you should set `torch.set_float32_matmul_precision('medium' | 'high')` which will trade-off precision for performance. For more details, read https://pytorch.org/docs/stable/generated/torch.set_float32_matmul_precision.html#torch.set_float32_matmul_precision
# Seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:06<00:00, 141.53it/s, v_num=41]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 83.32it/s, v_num=41]
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=aa59baa8a7e646aca72798c33a445504
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/aa59baa8a7e646aca72798c33a445504/output/log
# Seed set to 42
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 42
# Seed set to 42
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 80.76it/s, v_num=42]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:14<00:00, 57.52it/s, v_num=42]
# {'tr-ble_params': 10826, 'seed': 42, 'accuracy': 0.3393} {'tr-ble_params': 109386, 'seed': 42, 'accuracy': 0.9526}
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=db32cd10f41b4da399ed8cab7b4d9d1e
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/db32cd10f41b4da399ed8cab7b4d9d1e/output/log
# Seed set to 0
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 0
# Seed set to 0
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:06<00:00, 126.42it/s, v_num=43]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:11<00:00, 77.76it/s, v_num=43]
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=31704468ca234924b2d6d1524c0a1e4e
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/31704468ca234924b2d6d1524c0a1e4e/output/log
# Seed set to 0
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 0
# Seed set to 0
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:09<00:00, 86.48it/s, v_num=44]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:14<00:00, 59.99it/s, v_num=44]
# {'tr-ble_params': 10826, 'seed': 0, 'accuracy': 0.3401} {'tr-ble_params': 109386, 'seed': 0, 'accuracy': 0.9512}
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=6acb1b8dcbf541db8b766467eef9d4e3
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/6acb1b8dcbf541db8b766467eef9d4e3/output/log
# Seed set to 17
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 17
# Seed set to 17
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:05<00:00, 148.07it/s, v_num=45]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 84.62it/s, v_num=45]
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=0ffa6699de664950b4ae8751e62af64e
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/0ffa6699de664950b4ae8751e62af64e/output/log
# Seed set to 17
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 17
# Seed set to 17
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:09<00:00, 86.55it/s, v_num=46]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:14<00:00, 60.21it/s, v_num=46]
# {'tr-ble_params': 10826, 'seed': 17, 'accuracy': 0.3358} {'tr-ble_params': 109386, 'seed': 17, 'accuracy': 0.9471}
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=e5d7b95810394dc1b625b25b26ffa978
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/e5d7b95810394dc1b625b25b26ffa978/output/log
# Seed set to 9
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 9
# Seed set to 9
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:05<00:00, 147.72it/s, v_num=47]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 84.09it/s, v_num=47]
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=d68d89f6153e48e59660ea7fb72ddfba
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/d68d89f6153e48e59660ea7fb72ddfba/output/log
# Seed set to 9
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 9
# Seed set to 9
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 84.89it/s, v_num=48]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:14<00:00, 59.57it/s, v_num=48]
# {'tr-ble_params': 10826, 'seed': 9, 'accuracy': 0.3394} {'tr-ble_params': 109386, 'seed': 9, 'accuracy': 0.9515}
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=333d2b5ff3b84a3eb940c4b3043445e4
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/333d2b5ff3b84a3eb940c4b3043445e4/output/log
# Seed set to 3
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 3
# Seed set to 3
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 10.8 K | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 10.8 K    Trainable params
# 0         Non-trainable params
# 10.8 K    Total params
# 0.043     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:06<00:00, 142.98it/s, v_num=49]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:10<00:00, 80.86it/s, v_num=49]
# Could not read Jupyter Notebook: No module named 'nbconvert'
# Please install nbconvert using "pip install nbconvert"
# ClearML Task: created new task id=737cf8ee6e28491e843109a6da59b62e
# ClearML results page: https://app.clear.ml/projects/c366fe6ac95b477a877f15eaa5ddbcf0/experiments/737cf8ee6e28491e843109a6da59b62e/output/log
# Seed set to 3
# Parameters must be of builtin type (General/mean[ndarray], General/std[ndarray])
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Seed set to 3
# Seed set to 3
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type             | Params | Mode
# -----------------------------------------------------
# 0 | model   | MLP              | 109 K  | train
# 1 | loss_fn | CrossEntropyLoss | 0      | train
# -----------------------------------------------------
# 109 K     Trainable params
# 0         Non-trainable params
# 109 K     Total params
# 0.438     Total estimated model params size (MB)
# 7         Modules in train mode
# 0         Modules in eval mode
# Sanity Checking: |          | 0/? [00:00<?, ?it/s]
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'val_dataloader' to speed up the dataloader worker initialization.
# c:\Users\lexan\miniconda3\envs\mainenv\Lib\site-packages\pytorch_lightning\trainer\connectors\data_connector.py:420: UserWarning:
#
# Consider setting `persistent_workers=True` in 'train_dataloader' to speed up the dataloader worker initialization.
# Epoch 4: 100%|██████████| 860/860 [00:09<00:00, 88.49it/s, v_num=50]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 860/860 [00:13<00:00, 61.48it/s, v_num=50]
# {'tr-ble_params': 10826, 'seed': 3, 'accuracy': 0.3396} {'tr-ble_params': 109386, 'seed': 3, 'accuracy': 0.9523}

# %%
{'tr-ble_params': 10826, 'seed': 42, 'accuracy': 0.3393} {'tr-ble_params': 109386, 'seed': 42, 'accuracy': 0.9517}
{'tr-ble_params': 10826, 'seed': 0, 'accuracy': 0.3401} {'tr-ble_params': 109386, 'seed': 0, 'accuracy': 0.9516}
{'tr-ble_params': 10826, 'seed': 17, 'accuracy': 0.3358} {'tr-ble_params': 109386, 'seed': 17, 'accuracy': 0.9481}
{'tr-ble_params': 10826, 'seed': 9, 'accuracy': 0.3394} {'tr-ble_params': 109386, 'seed': 9, 'accuracy': 0.9533}
{'tr-ble_params': 10826, 'seed': 3, 'accuracy': 0.3396} {'tr-ble_params': 109386, 'seed': 3, 'accuracy': 0.952}

# %%
#Enter your code here to plot the figure using Json data from ClearML
from IPython.display import Image, display
print('Seed 42, tabular')
display(Image('NVIDIA_Overlay_iDE7ZNm6WG.png'))
print('Seed 42, image')
display(Image('NVIDIA_Overlay_wtyXbPCj0s.png'))

print('Seed 0, tabular')
display(Image('NVIDIA_Overlay_afSWQ9g1Dj.png'))

print('Seed 0, image')
display(Image('NVIDIA_Overlay_VRtJfWzooq.png'))

print('Seed 17, tabular')
display(Image('NVIDIA_Overlay_0zdHfxgOCY.png'))

print('Seed 17, image')
display(Image('NVIDIA_Overlay_XSCiYL6211.png'))

print('Seed 9, tabular')
display(Image('NVIDIA_Overlay_U09LSmg5am.png'))

print('Seed 9, image')
display(Image('NVIDIA_Overlay_lpxAQ37jdn.png'))

print('Seed 3, tabular')
display(Image('NVIDIA_Overlay_w8vI8joT9O.png'))

print('Seed 3, image')
display(Image('NVIDIA_Overlay_u0jN5CmG7U.png'))
# Out:
# Seed 42, tabular
# Seed 42, image
# Seed 0, tabular
# Seed 0, image
# Seed 17, tabular
# Seed 17, image
# Seed 9, tabular
# Seed 9, image
# Seed 3, tabular
# Seed 3, image

# %% [markdown]
# **Figure 1.** Comparison of the validation plots for runs with different model initializations (using different seeds).

# %% [markdown]
# Summarizing the result, the first (image processing) and the second (hand-designed features processing) approaches demonstrated accuracy of $ 95.07 \pm 0.26$, and $ 33.76 \pm 0.22$, respectively.

# %% [markdown]
# # Conclusion

# %% [markdown]
# На основании проведенных экспериментов, можно придти к выводу о том, что случайная величина, с которой происходит инициализация и обучение модели, не так важна, как выбор самой модели, ее архитектуры. Показания точности для каждой из моделей имеют значения в пределах маленькой погрешности в зависимости от seed'а, но между собой модели отличаются почти на 60 процентов. \
# Одна их таких причин, почему это произошло, является чрезмерное упрощение модели. Исходный MLP, принимающий на вход изображения 28х28 имеет 784 входных параметра. В то время как модель, использующая табличные данные - всего 14 (12 исходных, две добавил я). И хотя нам эти 14 фич (углы, линии, площади и так далее) могут показаться информативнее, чем 784 значения интенсивности каждого пикселя, 14 фич не хватает модели для качественного построения взаимосвязей. Число обучаемых параметров моделей отличается в 10 раз в пользу модели, работающей с изображениями, что является значительной разницей, когда мы говорим про такие архитектуры, как MLP. \
# Вероятно, если бы мы придумали еще несколько сотен фич, которые можно вытащить из изображения на основе классических алгоритмов компьютерного зрения, качество модели бы улучшилось, но в таком случае остро поднимается вопрос рациональности данного решения, так как для простого исполнения по MLP мы потратим меньше времени на разработку  (не нужно придумывать столько фич), и модель будет работать значительно быстрее, так как вычисление такого количества классических алгоритмов может занимать дольше времени, чем перемножение лишнего (если мы сравниваем MLP под изображение с 784 входами для пикселей и MLP под таблицу с, условно, 300 фичами) числа параметров на известные веса
#
# Please note that the conclusion is not only a declaration of the obtained results. It should also answer relevant questions related to the work, providing insights that enhance the reader's understanding, make their life a bit easier, and contribute to making the world a bit better — or at least a bit clearer.

# %% [markdown]
# # Questions

# %% [markdown]
# 1. How would you use ClearML to track experiments and compare the performance of different models?
# 2. What is the role of the random seed in training, and how does it affect reproducibility?
# 3. What is the purpose of the `prepare_data` method in the `MNISTDataModule`?
# 4. Why is the dataset split into training, validation, and test sets? What is the role of each set?
# 5. What does the `transforms.Normalize` function do, and why is it important for training neural networks?
# 6. Explain the architecture of the MLP model used in this lab. What are the dimensions of the input layer, hidden layers, and output layer? Why is the input size `28 * 28` for the MNIST dataset?
# 7. What loss function is used in this lab, and why is it suitable for this task? Which optimizer is used, and what is its learning rate?
# 8. What transformations are applied to the MNIST dataset before training? Why is normalization important, and what values are used for normalization in this lab?
# 9. What are the geometric features extracted from the MNIST images in the `extract_features` function? Explain each feature briefly.
# 10. What is the purpose of the `TabularDataModule`? How does it differ from the `MNISTDataModule`?
# 11. How does the `TabularDataModule` handle the conversion of image data into tabular data?
# 12. What is the role of the `TensorDataset` class in the `TabularDataModule`?
# 13. How does the `configure_optimizers` method work, and why is it necessary?
# 14. What is the significance of the `trainer.fit` and `trainer.test` methods in PyTorch Lightning?
# 15. What is the purpose of the `self.log` method in PyTorch Lightning? Where can you view the logged metrics?
# 16. Are the models prone to overfitting? Was this possibility considered and addressed during the modeling process?
# 17. How is accuracy calculated during the testing phase? What does the confusion matrix represent, and how can it help in evaluating the model's performance?
# 18. What does the "Top Losses" visualization represent? How can it help in debugging or improving the model?
#
# ## Bonus Questions (Optional)
# 1. What is the purpose of using ClearML in this lab? How does it help in managing machine learning experiments, in general?
# 2. What are the advantages and disadvantages of using handcrafted features (e.g., geometric features) versus raw pixel values for image classification?
# 3. How would you adapt the `TabularDataModule` and `TabularModel` for a different dataset (e.g., CIFAR-10)?
# 4. How would you modify the `TabularDataModule` to include additional features (e.g., histogram of pixel intensities)?
# 5. What are the challenges of using handcrafted features for more complex datasets (e.g., high-resolution images)?
# 6. How would you modify the `MLP` architecture to improve its performance on the tabular dataset?
# 7. What other machine learning models (e.g., decision trees, random forests) could be used for the tabular dataset, and how would you implement them?
# 8. How would you perform hyperparameter tuning (e.g., learning rate, batch size) for the `TabularModel`?
# 9. What additional metrics (e.g., precision, recall, F1-score) could you log to evaluate the model’s performance?
