# %% [markdown]
# <a href="https://colab.research.google.com/github/Mechanics-Mechatronics-and-Robotics/CV-2025/blob/main/Week_12/Lab9_object_tracking_multi_object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 9. Object Tracking. YOLO and DeepSORT.

# %% [markdown]
# Let's start with installing packages, it takes some time...

# %%
# !pip install ultralytics
# !git clone https://github.com/nwojke/deep_sort.git
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.104-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.21.0+cu124)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Downloading ultralytics-8.3.104-py3-none-any.whl (994 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.1/994.1 kB 17.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 66.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 48.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 864.2 kB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 76.9 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.104 ultralytics-thop-2.0.14
# Cloning into 'deep_sort'...
# remote: Enumerating objects: 167, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 167 (delta 6), reused 13 (delta 6), pack-reused 141 (from 1)
# Receiving objects: 100% (167/167), 86.13 KiB | 5.38 MiB/s, done.
# Resolving deltas: 100% (84/84), done.

# %% [markdown]
# Import libraries...

# %%
import random
import cv2
from ultralytics import YOLO

from deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from deep_sort.tools import generate_detections as gdet
from deep_sort.deep_sort import nn_matching
from deep_sort.deep_sort.detection import Detection
import numpy as np

# %% [markdown]
# More details about YOLO and DeepSORT:
#
# https://habr.com/ru/articles/514450/
#
# ![](https://habrastorage.org/r/w1560/webt/q_/6e/hz/q_6ehzuef4yaip17avcipq8wevg.png)

# %% [markdown]
# Upload video and weights for

# %%
# !gdown 1jcWKM2sIPqIdNtNj0rKmLPgHVvCP1djj
# !gdown 1JJDZMgj6zPYI7YcRazwB3nz7bg6tnMW4
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1jcWKM2sIPqIdNtNj0rKmLPgHVvCP1djj
# To: /content/people.mp4
# 100% 4.23M/4.23M [00:00<00:00, 25.7MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1JJDZMgj6zPYI7YcRazwB3nz7bg6tnMW4
# To: /content/mars-small128.pb
# 100% 11.2M/11.2M [00:00<00:00, 29.4MB/s]

# %% [markdown]
# Let's download our model.
#
# Some details for training and how to work with YOLO can be found here:
#
# https://colab.research.google.com/github/ultralytics/ultralytics/blob/main/examples/tutorial.ipynb

# %%
class Tracker:
    tracker = None
    encoder = None
    tracks = None

    def __init__(self):
        max_cosine_distance = 0.4
        nn_budget = None

        encoder_model_filename = 'mars-small128.pb'

        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = DeepSortTracker(metric)
        self.encoder = gdet.create_box_encoder(encoder_model_filename, batch_size=1)

    def update(self, frame, detections):

        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self.update_tracks()
            return

        bboxes = np.asarray([d[:-1] for d in detections])
        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, 0:2]
        scores = [d[-1] for d in detections]

        features = self.encoder(frame, bboxes)

        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            dets.append(Detection(bbox, scores[bbox_id], features[bbox_id]))

        self.tracker.predict()
        self.tracker.update(dets)
        self.update_tracks()

    def update_tracks(self):
        tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()

            id = track.track_id

            tracks.append(Track(id, bbox))

        self.tracks = tracks


class Track:
    track_id = None
    bbox = None

    def __init__(self, id, bbox):
        self.track_id = id
        self.bbox = bbox

# %%
video_path = 'people.mp4'
video_out_path = 'out.mp4'

cap = cv2.VideoCapture(video_path)
ret, frame = cap.read()

cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), cap.get(cv2.CAP_PROP_FPS),
                          (frame.shape[1], frame.shape[0]))

model = YOLO("yolov8n.pt")

tracker = Tracker()

colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

detection_threshold = 0.5

while ret:

    results = model(frame)

    for result in results:
        detections = []
        for r in result.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = r
            x1 = int(x1)
            x2 = int(x2)
            y1 = int(y1)
            y2 = int(y2)
            class_id = int(class_id)
            if score > detection_threshold:
                detections.append([x1, y1, x2, y2, score])

        tracker.update(frame, detections)

        for track in tracker.tracks:
            bbox = track.bbox
            x1, y1, x2, y2 = bbox
            track_id = track.track_id

            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (colors[track_id % len(colors)]), 3)

    cap_out.write(frame)
    ret, frame = cap.read()

cap.release()
cap_out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 35 persons, 2 birds, 312.8ms
# Speed: 18.4ms preprocess, 312.8ms inference, 35.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 131.6ms
# Speed: 3.5ms preprocess, 131.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 birds, 137.7ms
# Speed: 3.1ms preprocess, 137.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 125.8ms
# Speed: 9.8ms preprocess, 125.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 130.3ms
# Speed: 2.5ms preprocess, 130.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 132.7ms
# Speed: 2.4ms preprocess, 132.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 3 birds, 132.3ms
# Speed: 4.5ms preprocess, 132.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 129.9ms
# Speed: 3.1ms preprocess, 129.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 126.9ms
# Speed: 3.2ms preprocess, 126.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 birds, 122.4ms
# Speed: 3.6ms preprocess, 122.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 129.0ms
# Speed: 3.1ms preprocess, 129.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 200.2ms
# Speed: 3.0ms preprocess, 200.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 212.2ms
# Speed: 2.9ms preprocess, 212.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 3 birds, 182.7ms
# Speed: 3.3ms preprocess, 182.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 4 birds, 127.7ms
# Speed: 3.8ms preprocess, 127.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 4 birds, 143.2ms
# Speed: 3.2ms preprocess, 143.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 3 birds, 126.5ms
# Speed: 2.8ms preprocess, 126.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 135.6ms
# Speed: 2.8ms preprocess, 135.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 121.4ms
# Speed: 4.8ms preprocess, 121.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 124.8ms
# Speed: 3.0ms preprocess, 124.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 1 dog, 131.4ms
# Speed: 2.9ms preprocess, 131.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 128.1ms
# Speed: 2.9ms preprocess, 128.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 1 dog, 132.9ms
# Speed: 2.8ms preprocess, 132.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 121.5ms
# Speed: 2.7ms preprocess, 121.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 125.5ms
# Speed: 3.0ms preprocess, 125.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 120.0ms
# Speed: 2.4ms preprocess, 120.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 124.9ms
# Speed: 3.0ms preprocess, 124.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 123.4ms
# Speed: 3.8ms preprocess, 123.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 126.3ms
# Speed: 3.2ms preprocess, 126.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 121.0ms
# Speed: 2.5ms preprocess, 121.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 127.4ms
# Speed: 3.0ms preprocess, 127.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 162.1ms
# Speed: 2.6ms preprocess, 162.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 194.2ms
# Speed: 3.0ms preprocess, 194.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 189.2ms
# Speed: 2.7ms preprocess, 189.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 121.0ms
# Speed: 2.8ms preprocess, 121.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 124.9ms
# Speed: 3.3ms preprocess, 124.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 132.3ms
# Speed: 3.2ms preprocess, 132.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 123.0ms
# Speed: 3.8ms preprocess, 123.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 132.4ms
# Speed: 3.1ms preprocess, 132.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 161.6ms
# Speed: 3.2ms preprocess, 161.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 124.8ms
# Speed: 2.9ms preprocess, 124.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 2 birds, 131.6ms
# Speed: 3.2ms preprocess, 131.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 birds, 122.8ms
# Speed: 3.7ms preprocess, 122.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 133.1ms
# Speed: 3.2ms preprocess, 133.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 2 birds, 122.6ms
# Speed: 3.0ms preprocess, 122.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 2 birds, 124.1ms
# Speed: 2.8ms preprocess, 124.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 124.4ms
# Speed: 2.9ms preprocess, 124.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 142.5ms
# Speed: 3.3ms preprocess, 142.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 121.2ms
# Speed: 2.4ms preprocess, 121.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 126.3ms
# Speed: 2.8ms preprocess, 126.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 1 dog, 123.9ms
# Speed: 3.0ms preprocess, 123.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 124.2ms
# Speed: 3.3ms preprocess, 124.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 212.3ms
# Speed: 3.0ms preprocess, 212.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 2 birds, 1 dog, 195.6ms
# Speed: 2.9ms preprocess, 195.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 1 dog, 196.0ms
# Speed: 3.1ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 127.0ms
# Speed: 2.8ms preprocess, 127.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 123.2ms
# Speed: 2.9ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 horse, 121.4ms
# Speed: 2.8ms preprocess, 121.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 123.2ms
# Speed: 3.0ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 135.5ms
# Speed: 3.0ms preprocess, 135.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 122.1ms
# Speed: 2.8ms preprocess, 122.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 125.8ms
# Speed: 2.5ms preprocess, 125.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 125.7ms
# Speed: 2.9ms preprocess, 125.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 123.8ms
# Speed: 2.8ms preprocess, 123.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 128.2ms
# Speed: 2.8ms preprocess, 128.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 122.4ms
# Speed: 2.4ms preprocess, 122.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 122.0ms
# Speed: 3.0ms preprocess, 122.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 125.1ms
# Speed: 3.1ms preprocess, 125.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 124.9ms
# Speed: 2.9ms preprocess, 124.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 129.0ms
# Speed: 3.0ms preprocess, 129.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 121.9ms
# Speed: 3.0ms preprocess, 121.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 bird, 176.5ms
# Speed: 3.0ms preprocess, 176.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 196.3ms
# Speed: 2.9ms preprocess, 196.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 42 persons, 192.7ms
# Speed: 2.9ms preprocess, 192.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 125.3ms
# Speed: 3.0ms preprocess, 125.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 1 bird, 123.7ms
# Speed: 3.1ms preprocess, 123.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 1 bird, 126.6ms
# Speed: 2.4ms preprocess, 126.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 123.1ms
# Speed: 3.3ms preprocess, 123.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 3 birds, 122.2ms
# Speed: 3.2ms preprocess, 122.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 3 birds, 121.8ms
# Speed: 4.5ms preprocess, 121.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 3 birds, 138.2ms
# Speed: 3.1ms preprocess, 138.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 3 birds, 126.2ms
# Speed: 3.8ms preprocess, 126.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 bird, 125.9ms
# Speed: 3.4ms preprocess, 125.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 persons, 127.1ms
# Speed: 2.7ms preprocess, 127.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 2 birds, 125.9ms
# Speed: 2.7ms preprocess, 125.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 1 horse, 124.5ms
# Speed: 3.7ms preprocess, 124.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 129.9ms
# Speed: 3.1ms preprocess, 129.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 129.2ms
# Speed: 6.0ms preprocess, 129.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 125.7ms
# Speed: 3.3ms preprocess, 125.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 127.0ms
# Speed: 3.1ms preprocess, 127.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 persons, 124.6ms
# Speed: 3.3ms preprocess, 124.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 122.6ms
# Speed: 2.6ms preprocess, 122.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 39 persons, 188.1ms
# Speed: 3.0ms preprocess, 188.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 persons, 1 backpack, 196.6ms
# Speed: 3.1ms preprocess, 196.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 124.9ms
# Speed: 4.0ms preprocess, 124.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 127.2ms
# Speed: 2.6ms preprocess, 127.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 125.0ms
# Speed: 2.4ms preprocess, 125.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 dog, 134.1ms
# Speed: 2.7ms preprocess, 134.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 124.8ms
# Speed: 2.9ms preprocess, 124.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 127.8ms
# Speed: 2.3ms preprocess, 127.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 backpack, 128.1ms
# Speed: 3.8ms preprocess, 128.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 2 backpacks, 120.7ms
# Speed: 3.1ms preprocess, 120.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 1 backpack, 123.7ms
# Speed: 3.0ms preprocess, 123.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 122.3ms
# Speed: 2.3ms preprocess, 122.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 140.3ms
# Speed: 2.8ms preprocess, 140.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 194.8ms
# Speed: 3.6ms preprocess, 194.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 189.5ms
# Speed: 2.8ms preprocess, 189.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 201.6ms
# Speed: 3.0ms preprocess, 201.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 124.9ms
# Speed: 5.6ms preprocess, 124.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 122.5ms
# Speed: 3.0ms preprocess, 122.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 152.7ms
# Speed: 8.5ms preprocess, 152.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 handbag, 191.2ms
# Speed: 2.9ms preprocess, 191.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 dog, 195.7ms
# Speed: 2.9ms preprocess, 195.7ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 130.6ms
# Speed: 3.0ms preprocess, 130.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 125.3ms
# Speed: 2.8ms preprocess, 125.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 123.1ms
# Speed: 3.0ms preprocess, 123.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 121.8ms
# Speed: 4.1ms preprocess, 121.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 127.6ms
# Speed: 3.1ms preprocess, 127.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 123.2ms
# Speed: 4.3ms preprocess, 123.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 123.9ms
# Speed: 2.4ms preprocess, 123.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 dog, 127.8ms
# Speed: 3.2ms preprocess, 127.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 129.7ms
# Speed: 2.8ms preprocess, 129.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 120.6ms
# Speed: 3.9ms preprocess, 120.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 241.0ms
# Speed: 3.0ms preprocess, 241.0ms inference, 8.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 35 persons, 1 bird, 124.3ms
# Speed: 3.0ms preprocess, 124.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 36 persons, 1 bird, 120.6ms
# Speed: 3.0ms preprocess, 120.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 37 persons, 1 bird, 126.9ms
# Speed: 3.2ms preprocess, 126.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 121.9ms
# Speed: 3.5ms preprocess, 121.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 123.0ms
# Speed: 2.5ms preprocess, 123.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 1 bird, 121.1ms
# Speed: 3.7ms preprocess, 121.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 128.1ms
# Speed: 3.7ms preprocess, 128.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 188.5ms
# Speed: 3.0ms preprocess, 188.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 185.5ms
# Speed: 3.2ms preprocess, 185.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 167.0ms
# Speed: 2.9ms preprocess, 167.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 124.9ms
# Speed: 4.4ms preprocess, 124.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 119.0ms
# Speed: 2.9ms preprocess, 119.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 backpack, 125.1ms
# Speed: 3.1ms preprocess, 125.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 backpack, 121.4ms
# Speed: 3.0ms preprocess, 121.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 122.3ms
# Speed: 3.3ms preprocess, 122.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 suitcase, 121.0ms
# Speed: 3.7ms preprocess, 121.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 122.1ms
# Speed: 2.4ms preprocess, 122.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 121.7ms
# Speed: 3.1ms preprocess, 121.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 120.3ms
# Speed: 3.5ms preprocess, 120.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 117.0ms
# Speed: 3.1ms preprocess, 117.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 124.4ms
# Speed: 2.6ms preprocess, 124.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 121.9ms
# Speed: 3.0ms preprocess, 121.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 125.3ms
# Speed: 2.8ms preprocess, 125.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 140.2ms
# Speed: 3.1ms preprocess, 140.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 124.8ms
# Speed: 5.0ms preprocess, 124.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 125.0ms
# Speed: 3.2ms preprocess, 125.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 118.3ms
# Speed: 2.4ms preprocess, 118.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 120.5ms
# Speed: 2.5ms preprocess, 120.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 190.8ms
# Speed: 3.0ms preprocess, 190.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 180.5ms
# Speed: 3.9ms preprocess, 180.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 202.8ms
# Speed: 2.9ms preprocess, 202.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 118.8ms
# Speed: 2.4ms preprocess, 118.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 126.6ms
# Speed: 2.9ms preprocess, 126.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 120.8ms
# Speed: 2.7ms preprocess, 120.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 125.9ms
# Speed: 2.9ms preprocess, 125.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 124.9ms
# Speed: 2.6ms preprocess, 124.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 244.0ms
# Speed: 7.8ms preprocess, 244.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 151.1ms
# Speed: 6.8ms preprocess, 151.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 128.8ms
# Speed: 2.9ms preprocess, 128.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 305.3ms
# Speed: 3.0ms preprocess, 305.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 126.5ms
# Speed: 3.4ms preprocess, 126.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 126.4ms
# Speed: 3.1ms preprocess, 126.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 279.4ms
# Speed: 4.3ms preprocess, 279.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 135.0ms
# Speed: 3.3ms preprocess, 135.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 216.9ms
# Speed: 5.1ms preprocess, 216.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 190.6ms
# Speed: 2.9ms preprocess, 190.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 231.9ms
# Speed: 3.3ms preprocess, 231.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 173.7ms
# Speed: 4.6ms preprocess, 173.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 148.6ms
# Speed: 3.3ms preprocess, 148.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 152.2ms
# Speed: 3.0ms preprocess, 152.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 148.7ms
# Speed: 3.6ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 248.4ms
# Speed: 3.3ms preprocess, 248.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 126.0ms
# Speed: 3.6ms preprocess, 126.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 birds, 142.7ms
# Speed: 3.0ms preprocess, 142.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 122.0ms
# Speed: 4.7ms preprocess, 122.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 145.4ms
# Speed: 2.9ms preprocess, 145.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 148.4ms
# Speed: 2.9ms preprocess, 148.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 146.5ms
# Speed: 3.8ms preprocess, 146.5ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 120.9ms
# Speed: 2.6ms preprocess, 120.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 121.3ms
# Speed: 2.6ms preprocess, 121.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 122.5ms
# Speed: 4.1ms preprocess, 122.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 119.2ms
# Speed: 2.9ms preprocess, 119.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 145.2ms
# Speed: 3.0ms preprocess, 145.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 161.1ms
# Speed: 3.1ms preprocess, 161.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 197.4ms
# Speed: 4.1ms preprocess, 197.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 227.5ms
# Speed: 3.4ms preprocess, 227.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 222.2ms
# Speed: 2.7ms preprocess, 222.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 148.0ms
# Speed: 3.0ms preprocess, 148.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 147.7ms
# Speed: 3.2ms preprocess, 147.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 146.3ms
# Speed: 2.9ms preprocess, 146.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 139.4ms
# Speed: 3.1ms preprocess, 139.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 150.6ms
# Speed: 5.8ms preprocess, 150.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 144.6ms
# Speed: 3.9ms preprocess, 144.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 handbag, 150.3ms
# Speed: 3.8ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 141.7ms
# Speed: 3.0ms preprocess, 141.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 157.5ms
# Speed: 3.0ms preprocess, 157.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 dog, 1 handbag, 154.2ms
# Speed: 3.4ms preprocess, 154.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 174.0ms
# Speed: 3.0ms preprocess, 174.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 144.9ms
# Speed: 3.0ms preprocess, 144.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 147.2ms
# Speed: 3.8ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 150.3ms
# Speed: 3.1ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 1 horse, 1 handbag, 147.2ms
# Speed: 4.6ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 142.4ms
# Speed: 3.0ms preprocess, 142.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 backpacks, 147.3ms
# Speed: 5.8ms preprocess, 147.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 237.8ms
# Speed: 2.9ms preprocess, 237.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 218.5ms
# Speed: 3.0ms preprocess, 218.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 birds, 304.2ms
# Speed: 10.1ms preprocess, 304.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 122.5ms
# Speed: 2.4ms preprocess, 122.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 birds, 122.9ms
# Speed: 3.3ms preprocess, 122.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 birds, 197.2ms
# Speed: 3.6ms preprocess, 197.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 3 birds, 1 handbag, 125.2ms
# Speed: 7.7ms preprocess, 125.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 birds, 1 backpack, 122.6ms
# Speed: 3.4ms preprocess, 122.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 birds, 1 handbag, 145.1ms
# Speed: 4.6ms preprocess, 145.1ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 124.9ms
# Speed: 3.0ms preprocess, 124.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 162.5ms
# Speed: 3.0ms preprocess, 162.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 161.7ms
# Speed: 3.5ms preprocess, 161.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 handbag, 157.3ms
# Speed: 13.7ms preprocess, 157.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 handbag, 147.0ms
# Speed: 3.0ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 skis, 153.1ms
# Speed: 3.3ms preprocess, 153.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 5 birds, 1 skis, 142.0ms
# Speed: 3.1ms preprocess, 142.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 4 birds, 1 skis, 147.9ms
# Speed: 2.9ms preprocess, 147.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 4 birds, 1 skis, 157.0ms
# Speed: 3.5ms preprocess, 157.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 24 persons, 5 birds, 1 skis, 147.1ms
# Speed: 3.3ms preprocess, 147.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 persons, 2 birds, 1 handbag, 1 skis, 173.8ms
# Speed: 3.1ms preprocess, 173.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 197.7ms
# Speed: 5.1ms preprocess, 197.7ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 1 handbag, 186.3ms
# Speed: 5.6ms preprocess, 186.3ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 184.1ms
# Speed: 5.7ms preprocess, 184.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 2 handbags, 188.3ms
# Speed: 2.9ms preprocess, 188.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 2 handbags, 212.5ms
# Speed: 3.3ms preprocess, 212.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 birds, 1 handbag, 148.0ms
# Speed: 2.9ms preprocess, 148.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 birds, 1 handbag, 118.6ms
# Speed: 2.3ms preprocess, 118.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 120.1ms
# Speed: 3.6ms preprocess, 120.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 birds, 1 handbag, 118.7ms
# Speed: 4.6ms preprocess, 118.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 3 birds, 1 dog, 1 handbag, 123.6ms
# Speed: 2.9ms preprocess, 123.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 2 birds, 1 backpack, 132.6ms
# Speed: 2.4ms preprocess, 132.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 4 birds, 1 backpack, 121.1ms
# Speed: 2.8ms preprocess, 121.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 handbag, 125.5ms
# Speed: 4.3ms preprocess, 125.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 birds, 1 handbag, 147.4ms
# Speed: 2.8ms preprocess, 147.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 154.2ms
# Speed: 8.1ms preprocess, 154.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 4 birds, 1 dog, 1 handbag, 123.5ms
# Speed: 2.9ms preprocess, 123.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 birds, 1 handbag, 124.8ms
# Speed: 3.1ms preprocess, 124.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 136.7ms
# Speed: 2.7ms preprocess, 136.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 bird, 123.3ms
# Speed: 2.9ms preprocess, 123.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 handbag, 130.9ms
# Speed: 3.1ms preprocess, 130.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 motorcycle, 3 birds, 1 handbag, 126.3ms
# Speed: 2.8ms preprocess, 126.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 3 birds, 1 dog, 124.2ms
# Speed: 3.1ms preprocess, 124.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 1 kite, 132.9ms
# Speed: 3.1ms preprocess, 132.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 1 kite, 123.1ms
# Speed: 3.1ms preprocess, 123.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 149.1ms
# Speed: 3.4ms preprocess, 149.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 145.6ms
# Speed: 3.1ms preprocess, 145.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 handbag, 152.0ms
# Speed: 2.9ms preprocess, 152.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 handbag, 210.5ms
# Speed: 3.1ms preprocess, 210.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 handbag, 218.4ms
# Speed: 3.0ms preprocess, 218.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 222.6ms
# Speed: 13.9ms preprocess, 222.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 birds, 217.6ms
# Speed: 4.2ms preprocess, 217.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 2 birds, 1 backpack, 150.0ms
# Speed: 3.6ms preprocess, 150.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 3 birds, 1 backpack, 1 handbag, 153.0ms
# Speed: 5.2ms preprocess, 153.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 2 birds, 1 handbag, 147.5ms
# Speed: 3.4ms preprocess, 147.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 birds, 1 handbag, 148.9ms
# Speed: 3.0ms preprocess, 148.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 3 birds, 149.7ms
# Speed: 3.7ms preprocess, 149.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 4 birds, 147.5ms
# Speed: 3.7ms preprocess, 147.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 4 birds, 148.0ms
# Speed: 7.4ms preprocess, 148.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 birds, 153.8ms
# Speed: 3.1ms preprocess, 153.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 3 birds, 1 backpack, 145.6ms
# Speed: 3.1ms preprocess, 145.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 birds, 150.6ms
# Speed: 3.3ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 147.8ms
# Speed: 3.0ms preprocess, 147.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 146.5ms
# Speed: 3.1ms preprocess, 146.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 149.1ms
# Speed: 3.0ms preprocess, 149.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 148.8ms
# Speed: 2.9ms preprocess, 148.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 146.4ms
# Speed: 3.6ms preprocess, 146.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 150.3ms
# Speed: 6.1ms preprocess, 150.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 traffic light, 1 bird, 1 dog, 162.9ms
# Speed: 3.1ms preprocess, 162.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 1 dog, 148.0ms
# Speed: 2.9ms preprocess, 148.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 1 dog, 1 handbag, 156.4ms
# Speed: 6.8ms preprocess, 156.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 3 handbags, 150.7ms
# Speed: 3.8ms preprocess, 150.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 33 persons, 2 handbags, 243.5ms
# Speed: 10.8ms preprocess, 243.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 handbags, 230.0ms
# Speed: 3.0ms preprocess, 230.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 handbag, 195.7ms
# Speed: 9.0ms preprocess, 195.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 1 dog, 1 handbag, 152.4ms
# Speed: 4.1ms preprocess, 152.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 148.5ms
# Speed: 3.5ms preprocess, 148.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 150.7ms
# Speed: 3.2ms preprocess, 150.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 146.5ms
# Speed: 3.2ms preprocess, 146.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 dog, 154.2ms
# Speed: 3.1ms preprocess, 154.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 147.3ms
# Speed: 3.1ms preprocess, 147.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 147.7ms
# Speed: 3.8ms preprocess, 147.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 25 persons, 1 bird, 1 backpack, 146.0ms
# Speed: 6.9ms preprocess, 146.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 dog, 145.7ms
# Speed: 3.9ms preprocess, 145.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 150.6ms
# Speed: 3.5ms preprocess, 150.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 dog, 149.5ms
# Speed: 3.1ms preprocess, 149.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 1 dog, 153.0ms
# Speed: 3.0ms preprocess, 153.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 149.8ms
# Speed: 3.1ms preprocess, 149.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 149.9ms
# Speed: 3.1ms preprocess, 149.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 151.5ms
# Speed: 5.1ms preprocess, 151.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 2 birds, 1 backpack, 156.3ms
# Speed: 5.8ms preprocess, 156.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 159.3ms
# Speed: 3.1ms preprocess, 159.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 154.1ms
# Speed: 3.7ms preprocess, 154.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 dog, 147.2ms
# Speed: 3.2ms preprocess, 147.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 26 persons, 1 bird, 1 dog, 148.9ms
# Speed: 3.4ms preprocess, 148.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 228.8ms
# Speed: 3.1ms preprocess, 228.8ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 2 birds, 209.3ms
# Speed: 8.2ms preprocess, 209.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 2 birds, 252.3ms
# Speed: 2.9ms preprocess, 252.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 2 birds, 145.0ms
# Speed: 3.4ms preprocess, 145.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 2 birds, 143.8ms
# Speed: 3.0ms preprocess, 143.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 1 bird, 146.1ms
# Speed: 3.5ms preprocess, 146.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 149.8ms
# Speed: 2.9ms preprocess, 149.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 145.3ms
# Speed: 3.2ms preprocess, 145.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 157.3ms
# Speed: 8.2ms preprocess, 157.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 174.0ms
# Speed: 3.1ms preprocess, 174.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 dog, 149.3ms
# Speed: 3.3ms preprocess, 149.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 1 dog, 147.0ms
# Speed: 3.1ms preprocess, 147.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 153.6ms
# Speed: 4.2ms preprocess, 153.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 149.0ms
# Speed: 3.1ms preprocess, 149.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 bird, 158.9ms
# Speed: 3.0ms preprocess, 158.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 bird, 145.8ms
# Speed: 3.1ms preprocess, 145.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 umbrella, 155.0ms
# Speed: 4.0ms preprocess, 155.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 150.6ms
# Speed: 3.1ms preprocess, 150.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 147.3ms
# Speed: 6.3ms preprocess, 147.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 150.3ms
# Speed: 5.3ms preprocess, 150.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 153.0ms
# Speed: 3.4ms preprocess, 153.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 147.6ms
# Speed: 3.1ms preprocess, 147.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 27 persons, 150.0ms
# Speed: 3.1ms preprocess, 150.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 195.4ms
# Speed: 5.1ms preprocess, 195.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 217.3ms
# Speed: 3.6ms preprocess, 217.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 182.9ms
# Speed: 6.8ms preprocess, 182.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 153.3ms
# Speed: 4.0ms preprocess, 153.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 28 persons, 1 dog, 149.4ms
# Speed: 3.3ms preprocess, 149.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 160.8ms
# Speed: 3.0ms preprocess, 160.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 1 dog, 144.9ms
# Speed: 5.3ms preprocess, 144.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 29 persons, 153.0ms
# Speed: 4.3ms preprocess, 153.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 152.8ms
# Speed: 4.4ms preprocess, 152.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 153.6ms
# Speed: 3.5ms preprocess, 153.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 34 persons, 1 bird, 148.8ms
# Speed: 3.1ms preprocess, 148.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 30 persons, 1 bird, 151.4ms
# Speed: 5.4ms preprocess, 151.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 149.7ms
# Speed: 2.8ms preprocess, 149.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 149.4ms
# Speed: 3.1ms preprocess, 149.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 31 persons, 1 bird, 159.1ms
# Speed: 5.4ms preprocess, 159.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 32 persons, 1 bird, 148.6ms
# Speed: 2.8ms preprocess, 148.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)

# %%
import imageio
import matplotlib.animation as animation
from skimage.transform import resize
import matplotlib.pyplot as plt
from IPython.display import HTML

def display_video(video):
    fig = plt.figure(figsize=(3,3))  #Display size specification

    mov = []
    for i in range(len(video)):  #Append videos one by one to mov
        img = plt.imshow(video[i], animated=True)
        plt.axis('off')
        mov.append([img])

    #Animation creation
    anime = animation.ArtistAnimation(fig, mov, interval=50, repeat_delay=1000)

    plt.close()
    return anime

video = imageio.mimread('out.mp4', memtest=False)  #Loading video
video = [resize(frame, (256, 256))[..., :3] for frame in video]    #Size adjustment (if necessary)
HTML(display_video(video).to_html5_video())  #Inline video display in HTML5
# Out:
# <video width="300" height="300" controls autoplay loop>
#   <source type="video/mp4" src="...

# %% [markdown]
# # Homework (4 points)

# %% [markdown]
# In this homework you need to create your own model for tracking an object based on the custom dataset.
#
# Requirements:
#
# 1. You need to choose a model as a detector and a tracking algorithm to it
#
# 2. Choose or record your own video (it could be a video stream recorded on your smartphone or on a web camera, etc) for the purpose of detection and tracking
#
# 3. Prepare your own dataset and retrain your model so it can be able to detect a chosen class/object
#
# 4. Present your results by the following way:
#
# * Explain each part of architecture (detector+tracker) used in your solution. For example, if its YoloV8, what is it special about this model?
#
# * Briefly explain your dataset and object for detection\tracking purposes on the video
#
# * Make a Jupyter Notebook or python script that includes all the steps from reading video and training model to saving video with all the detection/tracking actions
#
# * Make sure that your code works correctly and DON'T forget to note where it should be executed (colab/locally/etc.)
#
# You are allowed to use any framework for detection and tracking steps.
#
# Example:
#
# https://medium.com/@serurays/object-detection-and-tracking-using-yolov8-and-deepsort-47046fc914e9
#
# GOOD LUCK!

# %%
# ** YOUR CODE HERE **
